# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from ydata_profiling import ProfileReport
import re

from sklearn.pipeline import Pipeline, make_pipeline

# %%
import tensorflow as tf
from sklearn.metrics import roc_auc_score,f1_score,accuracy_score
from sklearn.model_selection import train_test_split,StratifiedKFold,cross_val_score
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder
from skmultilearn.problem_transform import BinaryRelevance
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb

from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.calibration import calibration_curve
from sklearn.preprocessing import PolynomialFeatures
from catboost import Pool,CatBoostClassifier
from xgboost import XGBClassifier
from catboost import CatBoostRegressor
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn import svm, model_selection,tree, linear_model, neighbors, naive_bayes, ensemble 
from sklearn import discriminant_analysis, gaussian_process
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216 from C header, got 232 from PyObject

# %%
train_features = pd.read_csv('training_set_features.csv')
train_labels = pd.read_csv('training_set_labels.csv')
test_features = pd.read_csv('test_set_features.csv')
sub_format = pd.read_csv('submission_format.csv')

# %%
train_labels.drop('respondent_id',axis = 1,inplace = True)
frames = [train_features, train_labels]
df = pd.concat(frames, axis=1)

# %%
display(df.shape, df.head())
# Out:
# (26707, 38)
#    respondent_id  h1n1_concern  ...  h1n1_vaccine  seasonal_vaccine
# 0              0           1.0  ...             0                 0
# 1              1           3.0  ...             0                 1
# 2              2           1.0  ...             0                 0
# 3              3           1.0  ...             0                 1
# 4              4           2.0  ...             0                 0
#
# [5 rows x 38 columns]

# %%
df.isnull().sum()
# Out:
# respondent_id                      0
# h1n1_concern                      92
# h1n1_knowledge                   116
# behavioral_antiviral_meds         71
# behavioral_avoidance             208
# behavioral_face_mask              19
# behavioral_wash_hands             42
# behavioral_large_gatherings       87
# behavioral_outside_home           82
# behavioral_touch_face            128
# doctor_recc_h1n1                2160
# doctor_recc_seasonal            2160
# chronic_med_condition            971
# child_under_6_months             820
# health_worker                    804
# health_insurance               12274
# opinion_h1n1_vacc_effective      391
# opinion_h1n1_risk                388
# opinion_h1n1_sick_from_vacc      395
# opinion_seas_vacc_effective      462
# opinion_seas_risk                514
# opinion_seas_sick_from_vacc      537
# age_group                          0
# education                       1407
# race                               0
# sex                                0
# income_poverty                  4423
# marital_status                  1408
# rent_or_own                     2042
# employment_status               1463
# hhs_geo_region                     0
# census_msa                         0
# household_adults                 249
# household_children               249
# employment_industry            13330
# employment_occupation          13470
# h1n1_vaccine                       0
# seasonal_vaccine                   0
# dtype: int64

# %%
df.drop(['health_insurance','employment_industry','employment_occupation'],axis=1,inplace = True)

# %%
str_cols = df.select_dtypes(include = 'object').columns
df[str_cols].head()
# Out:
#        age_group         education  ... hhs_geo_region                census_msa
# 0  55 - 64 Years        < 12 Years  ...       oxchjgsf                   Non-MSA
# 1  35 - 44 Years          12 Years  ...       bhuqouqj  MSA, Not Principle  City
# 2  18 - 34 Years  College Graduate  ...       qufhixun  MSA, Not Principle  City
# 3      65+ Years          12 Years  ...       lrircsnp       MSA, Principle City
# 4  45 - 54 Years      Some College  ...       qufhixun  MSA, Not Principle  City
#
# [5 rows x 10 columns]

# %%
for col in df.columns:
    if df[col].isnull().sum() and df[col].dtypes != 'object':
        df[col].loc[(train_features[col].isnull())] = df[col].mean()
for col in df.columns:
    if df[col].isnull().sum() and df[col].dtypes == 'object':
        df[col].loc[(df[col].isnull())] = df[col].mode().max()
# Out:
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(train_features[col].isnull())] = df[col].mean()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(df[col].isnull())] = df[col].mode().max()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(df[col].isnull())] = df[col].mode().max()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(df[col].isnull())] = df[col].mode().max()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(df[col].isnull())] = df[col].mode().max()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3377083907.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[(df[col].isnull())] = df[col].mode().max()

# %%
df.isnull().sum()
# Out:
# respondent_id                  0
# h1n1_concern                   0
# h1n1_knowledge                 0
# behavioral_antiviral_meds      0
# behavioral_avoidance           0
# behavioral_face_mask           0
# behavioral_wash_hands          0
# behavioral_large_gatherings    0
# behavioral_outside_home        0
# behavioral_touch_face          0
# doctor_recc_h1n1               0
# doctor_recc_seasonal           0
# chronic_med_condition          0
# child_under_6_months           0
# health_worker                  0
# opinion_h1n1_vacc_effective    0
# opinion_h1n1_risk              0
# opinion_h1n1_sick_from_vacc    0
# opinion_seas_vacc_effective    0
# opinion_seas_risk              0
# opinion_seas_sick_from_vacc    0
# age_group                      0
# education                      0
# race                           0
# sex                            0
# income_poverty                 0
# marital_status                 0
# rent_or_own                    0
# employment_status              0
# hhs_geo_region                 0
# census_msa                     0
# household_adults               0
# household_children             0
# h1n1_vaccine                   0
# seasonal_vaccine               0
# dtype: int64

# %%
le = LabelEncoder()
for col in str_cols:
    df[col] = le.fit_transform(df[col])

# %%
df[str_cols].head()
# Out:
#    age_group  education  race  ...  employment_status  hhs_geo_region  census_msa
# 0          3          1     3  ...                  1               8           2
# 1          1          0     3  ...                  0               1           0
# 2          0          2     3  ...                  0               9           0
# 3          4          0     3  ...                  1               5           1
# 4          2          3     3  ...                  0               9           0
#
# [5 rows x 10 columns]

# %%
df['cleanliness'] =  df['behavioral_antiviral_meds']+ df['behavioral_avoidance']+\
                        df['behavioral_face_mask']+df['behavioral_wash_hands']+\
                       df['behavioral_large_gatherings'] + df['behavioral_outside_home']+\
                       df['behavioral_touch_face']

# %%
print(df[df["h1n1_vaccine"]==1].count()[1])
# Out:
# 5674

# %%
df['opinion'] = df['opinion_h1n1_vacc_effective'] + df['opinion_h1n1_risk']+\
                  df['opinion_h1n1_sick_from_vacc'] + df['opinion_seas_vacc_effective']+\
                  df['opinion_seas_risk'] + df['opinion_seas_sick_from_vacc']

# %%
df['opinion_h1n1'] = df['opinion_h1n1_vacc_effective'] + df['opinion_h1n1_risk']-\
                  df['opinion_h1n1_sick_from_vacc'] 
df['opinion_seasonal'] = df['opinion_seas_vacc_effective']+\
                  df['opinion_seas_risk'] - df['opinion_seas_sick_from_vacc']

# %%
df['concern>=2'] = np.where(df['h1n1_concern']>=2,1,0) 
# Since those who have concern>=2 have a pronounced effect on vaccination

df['good_opinion_vacc'] = np.where(df['opinion_seas_vacc_effective'] == 3,1,0)
#If the opinion is 3 it means he/she has a good opinion and is more likely to take the vaccine

df['good_knowledge'] = np.where(df['h1n1_knowledge'] == 2,1,0)
#Same kind of logic as mentioned previously

# %%
df['risk'] = np.where(df['opinion_h1n1_risk']>=4,1,0)

#data['sick'] = np.where(data['opinion_h1n1_sick_from_vacc'] == 3,1,0)

### Generating a column combining concern and knowledge, since they have seemingly good correlations!

df['concern_knowledge'] = df['h1n1_concern']+df['h1n1_knowledge']

## square of age group to subtely improve the correlation of that feature with the vaccine probabilty
df['a^2'] = df['age_group']*df['age_group']

# %%
df.head()
# Out:
#    respondent_id  h1n1_concern  h1n1_knowledge  ...  risk  concern_knowledge  a^2
# 0              0           1.0             0.0  ...     0                1.0    9
# 1              1           3.0             2.0  ...     1                5.0    1
# 2              2           1.0             1.0  ...     0                2.0    0
# 3              3           1.0             1.0  ...     0                2.0   16
# 4              4           2.0             1.0  ...     0                3.0    4
#
# [5 rows x 45 columns]

# %%
df.drop(['race','child_under_6_months','opinion_h1n1_sick_from_vacc','opinion_seas_sick_from_vacc','household_adults','behavioral_antiviral_meds','behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_antiviral_meds','marital_status',
           'behavioral_avoidance','behavioral_face_mask','income_poverty','hhs_geo_region','employment_status','education','census_msa'],axis=1,inplace = True)

Y_label = df[['h1n1_vaccine','seasonal_vaccine']]

# %%
df.drop(['respondent_id','h1n1_vaccine','seasonal_vaccine'],axis=1,inplace = True)
frames =[df,Y_label]
data = pd.concat(frames,axis=1)

# %%
features = data.columns[:-2]
print(features)
labels = ['h1n1_vaccine', 'seasonal_vaccine']
# Out:
# Index(['h1n1_concern', 'h1n1_knowledge', 'behavioral_wash_hands',
#        'behavioral_touch_face', 'doctor_recc_h1n1', 'doctor_recc_seasonal',
#        'chronic_med_condition', 'health_worker', 'opinion_h1n1_vacc_effective',
#        'opinion_h1n1_risk', 'opinion_seas_vacc_effective', 'opinion_seas_risk',
#        'age_group', 'sex', 'rent_or_own', 'household_children', 'cleanliness',
#        'opinion', 'opinion_h1n1', 'opinion_seasonal', 'concern>=2',
#        'good_opinion_vacc', 'good_knowledge', 'risk', 'concern_knowledge',
#        'a^2'],
#       dtype='object')

# %%
train,test = train_test_split(data,test_size = 0.2,shuffle = True)
x_train,y_train = train[features],train[labels]
x_test,y_test = test[features],test[labels]

# %%
def transform_test(Test_X):
    Test_X.drop(['respondent_id','health_insurance','employment_industry','employment_occupation'],axis=1,inplace = True)

    # All the NULL values are populated with the mode
            
    d = Test_X
    str_cols = d.select_dtypes(include = 'object').columns

    ### LabelEcoding all categorical types #####
    for col in Test_X.columns:
        if Test_X[col].isnull().sum() and Test_X[col].dtypes != 'object':
            Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
    for col in Test_X.columns:
        if Test_X[col].isnull().sum() and Test_X[col].dtypes == 'object':
            Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].mode().max()
    le = LabelEncoder()
    for col in str_cols:
        Test_X[col] = le.fit_transform(Test_X[col]) # Converts to int64
            
    data = d
    ### Synthesizing two new features cleanliness level of the individual and opinion of vaccine ####
    data['opinion'] = data['opinion_h1n1_vacc_effective'] + data['opinion_h1n1_risk']+\
                  data['opinion_h1n1_sick_from_vacc'] + data['opinion_seas_vacc_effective']+\
                  data['opinion_seas_risk'] + data['opinion_seas_sick_from_vacc']
    data['cleanliness'] =  data['behavioral_antiviral_meds']+ data['behavioral_avoidance']+\
                        data['behavioral_face_mask']+data['behavioral_wash_hands']+\
                       data['behavioral_large_gatherings'] + data['behavioral_outside_home']+\
                       data['behavioral_touch_face']
    data['opinion_h1n1'] = data['opinion_h1n1_vacc_effective'] + data['opinion_h1n1_risk']-\
                      data['opinion_h1n1_sick_from_vacc'] 
    data['opinion_seasonal'] = data['opinion_seas_vacc_effective']+\
                      data['opinion_seas_risk'] - data['opinion_seas_sick_from_vacc']

    data['concern>=2'] = np.where(data['h1n1_concern']>=2,1,0)
    data['good_opinion_vacc'] = np.where(data['opinion_seas_vacc_effective'] == 3,1,0) # 5 before
    data['good_knowledge'] = np.where(data['h1n1_knowledge'] == 2,1,0)
    data['risk'] = np.where(data['opinion_h1n1_risk']>=4,1,0)
    data['concern_knowledge'] = data['h1n1_concern']+data['h1n1_knowledge']
    data['a^2'] = data['age_group']*data['age_group']
    ###### Dropping other features #########
    data.drop(['race','child_under_6_months','opinion_h1n1_sick_from_vacc','opinion_seas_sick_from_vacc','household_adults','behavioral_antiviral_meds','behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_antiviral_meds','marital_status',
           'behavioral_avoidance','behavioral_face_mask','income_poverty','hhs_geo_region','employment_status','education','census_msa'],axis=1,inplace = True)
    Test_X = data
    return Test_X

# %%
Test_X = pd.read_csv('test_set_features.csv')
Test_X.shape
# Out:
# (26708, 36)

# %%
Test_X = transform_test(Test_X)
# Out:
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].median()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].mode().max()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].mode().max()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].mode().max()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].mode().max()
# C:\Users\zaida\AppData\Local\Temp\ipykernel_19380\3200031253.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_X[col].loc[(Test_X[col].isnull())] = Test_X[col].mode().max()

# %%
from sklearn import svm, tree, linear_model, neighbors, naive_bayes, ensemble, discriminant_analysis, gaussian_process
MLA = [
    #Ensemble Methods
    ensemble.AdaBoostClassifier(),
    ensemble.BaggingClassifier(),
    ensemble.ExtraTreesClassifier(),
    ensemble.GradientBoostingClassifier(),
    ensemble.RandomForestClassifier(),

    #Gaussian Processes
    #gaussian_process.GaussianProcessClassifier(),
    
    #GLM
    linear_model.LogisticRegressionCV(),
    linear_model.PassiveAggressiveClassifier(),
    linear_model.RidgeClassifierCV(),
    linear_model.SGDClassifier(),
    linear_model.Perceptron(),
    
    #Navies Bayes
    naive_bayes.BernoulliNB(),
    naive_bayes.GaussianNB(),
    
    #Nearest Neighbor
    neighbors.KNeighborsClassifier(),
    
    #SVM
    #svm.SVC(probability=True),
    #svm.NuSVC(probability=True),
    svm.LinearSVC(),
    
    #Trees    
    tree.DecisionTreeClassifier(),
    tree.ExtraTreeClassifier(),
    
    #Discriminant Analysis
    discriminant_analysis.LinearDiscriminantAnalysis(),
    discriminant_analysis.QuadraticDiscriminantAnalysis(),

    
    #xgboost: http://xgboost.readthedocs.io/en/latest/model.html
    XGBClassifier()    
    ]



#split dataset in cross-validation with this splitter class: http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.ShuffleSplit.html#sklearn.model_selection.ShuffleSplit
#note: this is an alternative to train_test_split
cv_split = model_selection.ShuffleSplit(n_splits = 10, test_size = .3, train_size = .6, random_state = 0 ) # run model 10x with 60/30 split intentionally leaving out 10%

#create table to compare MLA metrics
MLA_columns = ['MLA Name', 'MLA Parameters', 'MLA Test Accuracy Mean', 'MLA Test Accuracy 3*STD' ,'MLA Time']
MLA_compare = pd.DataFrame(columns = MLA_columns)

#create table to compare MLA predictions
MLA_predict = data['h1n1_vaccine']

#index through MLA and save performance to table
row_index = 0
data1 = data.copy()
for alg in MLA:
    data = data1
    #set name and parameters
    MLA_name = alg.__class__.__name__
    print('Executing ',MLA_name)
    MLA_compare.loc[row_index, 'MLA Name'] = MLA_name
    MLA_compare.loc[row_index, 'MLA Parameters'] = str(alg.get_params())
    
    #score model with cross validation: http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_validate.html#sklearn.model_selection.cross_validate
    cv_results = model_selection.cross_validate(alg, data[features], data['h1n1_vaccine'], cv  = cv_split)
    #print(cv_results.keys())
    MLA_compare.loc[row_index, 'MLA Time'] = cv_results['fit_time'].mean()
    #MLA_compare.loc[row_index, 'MLA Train Accuracy Mean'] = cv_results['train_score'].mean()
    MLA_compare.loc[row_index, 'MLA Test Accuracy Mean'] = cv_results['test_score'].mean()   
    #if this is a non-bias random sample, then +/-3 standard deviations (std) from the mean, should statistically capture 99.7% of the subsets
    MLA_compare.loc[row_index, 'MLA Test Accuracy 3*STD'] = cv_results['test_score'].std()*3   #let's know the worst that can happen!
    
    #save MLA predictions - see section 6 for usage
    alg.fit(data[features], data['h1n1_vaccine'])
    MLA_predict[MLA_name] = alg.predict(data[features])
    row_index+=1

    
#print and sort table: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_values.html
MLA_compare.sort_values(by = ['MLA Test Accuracy Mean'], ascending = False, inplace = True)
MLA_compare
# Out:
# Executing  AdaBoostClassifier
# Executing  BaggingClassifier
# Executing  ExtraTreesClassifier
# Executing  GradientBoostingClassifier
# Executing  RandomForestClassifier
# Executing  LogisticRegressionCV
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Executing  PassiveAggressiveClassifier
# Executing  RidgeClassifierCV
# Executing  SGDClassifier
# Executing  Perceptron
# Executing  BernoulliNB
# Executing  GaussianNB
# Executing  KNeighborsClassifier
# Executing  LinearSVC
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Executing  DecisionTreeClassifier
# Executing  ExtraTreeClassifier
# Executing  LinearDiscriminantAnalysis
# Executing  QuadraticDiscriminantAnalysis
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:887: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:887: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:887: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:887: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:887: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:887: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:887: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:887: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:887: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:887: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:887: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Executing  XGBClassifier
#                          MLA Name  ...  MLA Time
# 3      GradientBoostingClassifier  ...   1.86414
# 0              AdaBoostClassifier  ...  0.633092
# 5            LogisticRegressionCV  ...  2.664364
# 16     LinearDiscriminantAnalysis  ...  0.073048
# 7               RidgeClassifierCV  ...  0.052185
# 18                  XGBClassifier  ...  1.001622
# 4          RandomForestClassifier  ...  1.551251
# 2            ExtraTreesClassifier  ...  1.774846
# 1               BaggingClassifier  ...  0.553373
# 12           KNeighborsClassifier  ...  0.009895
# 13                      LinearSVC  ...   1.81016
# 8                   SGDClassifier  ...  0.293842
# 10                    BernoulliNB  ...  0.019133
# 6     PassiveAggressiveClassifier  ...  0.048524
# 15            ExtraTreeClassifier  ...  0.026145
# 17  QuadraticDiscriminantAnalysis  ...  0.031757
# 9                      Perceptron  ...  0.031005
# 14         DecisionTreeClassifier  ...   0.08854
# 11                     GaussianNB  ...  0.016349
#
# [19 rows x 5 columns]

# %%
#barplot using https://seaborn.pydata.org/generated/seaborn.barplot.html
sns.barplot(x='MLA Test Accuracy Mean', y = 'MLA Name', data = MLA_compare, color = 'm')

#prettify using pyplot: https://matplotlib.org/api/pyplot_api.html
plt.title('Machine Learning Algorithm Accuracy Score \n')
plt.xlabel('Accuracy Score (%)')
plt.ylabel('Algorithm')
# Out:
# Text(0, 0.5, 'Algorithm')

# %%
def find_acc(clf,X,truth,s):
    pred = clf.predict_proba(X.values)
    pred = pred.toarray()
    accuracy = roc_auc_score(truth,pred)
    print(s+" Accuracy is : ",accuracy*100)

# %%
from sklearn.model_selection import GridSearchCV
grid_1 = {      "n_estimators"      : [100,200,500],
               "criterion"         : ["gini", "entropy"],
               "max_features"      : ['sqrt','log2',0.2,0.5,0.8],
               "max_depth"         : [3,4,6,10],
               "min_samples_split" : [2, 5, 20,50] }
RF=RandomForestClassifier()
gs = GridSearchCV(RF, grid_1, n_jobs=-1, cv=2,verbose = True)

# %%
clf = BinaryRelevance(classifier=gs, require_dense=[True,True])
clf.fit(x_train,y_train)
find_acc(clf,x_train,y_train,'Training')
find_acc(clf,x_test,y_test,'Cross Validation')
# Out:
# Fitting 2 folds for each of 480 candidates, totalling 960 fits
# Fitting 2 folds for each of 480 candidates, totalling 960 fits
# Training Accuracy is :  88.22218852627925
# Cross Validation Accuracy is :  83.59651468451102

# %%
from sklearn.model_selection import RandomizedSearchCV
n_estimators = [100,200,500]
max_features = ['auto', 'sqrt']
max_depth = [15,20,25]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
bootstrap = [True, False]
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
rf = RandomForestClassifier()
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 20,\
                               cv = 3, verbose=2, random_state=42, n_jobs = -1)

# %%
clf = BinaryRelevance(classifier=rf_random, require_dense=[True,True])
clf.fit(x_train,y_train)
find_acc(clf,x_train,y_train,'Training')
find_acc(clf,x_test,y_test,'Cross Validation')
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Training Accuracy is :  95.03432789528556
# Cross Validation Accuracy is :  83.01238975816416

# %%
def NN_classifier(input_dim,output_dim):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(25,input_dim=input_dim,activation = 'relu'),
        tf.keras.layers.Dense(128,activation = 'relu'),
        tf.keras.layers.Dense(64,activation = 'relu'),
        tf.keras.layers.Dense(output_dim,activation = 'softmax')
    ])
    model.compile(loss = 'binary_crossentropy',optimizer = 'adam',metrics = ['accuracy'])
    return model

# %%
from sklearn.model_selection import GridSearchCV
param2 = {
            'learning_rate':     [0.01,0.1],
            'max_depth':         [2,3,4],
            'lambda':            [1.0,1.5],
            'subsample':        [0.1,0.2,0.3],
            'colsample_bytree': [0.3,0.5,0.6],
            'min_split_loss' :  [0.01,0.2],
            'min_split_size' : [2,4,6]
        }
classifier = XGBClassifier(feature_names = features,verbose = False)
xgb = GridSearchCV(classifier, param2, n_jobs=-1, cv=2,verbose = True)

# %%
clf = BinaryRelevance(classifier=xgb, require_dense=[True,True])
clf.fit(x_train,y_train)
find_acc(clf,x_train,y_train,'Training')
find_acc(clf,x_test,y_test,'Cross Validation')
# Out:
# Fitting 2 folds for each of 648 candidates, totalling 1296 fits
# [02:15:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "feature_names", "min_split_size", "verbose" } are not used.
#
# Fitting 2 folds for each of 648 candidates, totalling 1296 fits
# [02:19:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "feature_names", "min_split_size", "verbose" } are not used.
#
# Training Accuracy is :  86.1418225600605
# Cross Validation Accuracy is :  83.56803814022376

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import RandomizedSearchCV
n_estimators = [100,200]
max_features = ['auto', 'sqrt']
max_depth = [2,3,7,5,15,20,25]
max_depth.append(None)
min_samples_split = [0.2,0.3,0.6,1.2,1.5,2.0,3.0,4.0]
min_samples_leaf = [1, 2, 4]
bootstrap = [True, False]
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

rf = XGBClassifier(feature_names = features,verbose = False)
etc = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 20,\
                               cv = 4, verbose=2, random_state=42, n_jobs = -1)

# %%
clf = BinaryRelevance(classifier=etc, require_dense=[True,True])
clf.fit(x_train,y_train)
find_acc(clf,x_train,y_train,'Training')
find_acc(clf,x_test,y_test,'Cross Validation')
# Out:
# Fitting 4 folds for each of 20 candidates, totalling 80 fits
# [02:22:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "bootstrap", "feature_names", "max_features", "min_samples_leaf", "min_samples_split", "verbose" } are not used.
#
# Fitting 4 folds for each of 20 candidates, totalling 80 fits
# [02:25:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "bootstrap", "feature_names", "max_features", "min_samples_leaf", "min_samples_split", "verbose" } are not used.
#
# Training Accuracy is :  86.48762805894798
# Cross Validation Accuracy is :  83.40166940612794

# %%
cb_hps = {  
            'depth':              [2,3,4,5,7],
            'l2_leaf_reg':        [2,3,5,10],
            'random_seed':        [5,8,10],
            'colsample_bylevel': [0.3,0.5,0.6],
            'n_estimators':      [100,200]
        }

cb = CatBoostClassifier()
cbt = RandomizedSearchCV(estimator = cb, param_distributions = cb_hps, n_iter = 20,\
                               cv = 4, verbose=2, random_state=42, n_jobs = -1)

# %%
clf = BinaryRelevance(classifier=cbt, require_dense=[True,True])
clf.fit(x_train,y_train)
find_acc(clf,x_train,y_train,'Training')
find_acc(clf,x_test,y_test,'Cross Validation')
# Out:
# Fitting 4 folds for each of 20 candidates, totalling 80 fits
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 7 fits failed out of a total of 80.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\zaida\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\zaida\anaconda3\lib\site-packages\catboost\core.py", line 5131, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "c:\Users\zaida\anaconda3\lib\site-packages\catboost\core.py", line 2357, in _fit
#     self._train(
#   File "c:\Users\zaida\anaconda3\lib\site-packages\catboost\core.py", line 1761, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 4624, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 4673, in _catboost._CatBoost._train
# _catboost.CatBoostError: C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/libs/train_lib/dir_helper.cpp:20: Can't create train working dir: catboost_info
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\zaida\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.83360625 0.83318498 0.83332544 0.83140645
#  0.83126593 0.83491681 0.82775572 0.83159361 0.83632093 0.83444871
#  0.83379344 0.83646129 0.83664854 0.82775571 0.83524434 0.83267014
#  0.82845778 0.83468267]
#   warnings.warn(
# 0:	learn: 0.6729021	total: 156ms	remaining: 31.1s
# 1:	learn: 0.6525380	total: 166ms	remaining: 16.4s
# 2:	learn: 0.6343619	total: 176ms	remaining: 11.6s
# 3:	learn: 0.6172376	total: 186ms	remaining: 9.12s
# 4:	learn: 0.6014284	total: 196ms	remaining: 7.65s
# 5:	learn: 0.5865472	total: 207ms	remaining: 6.7s
# 6:	learn: 0.5730163	total: 218ms	remaining: 6s
# 7:	learn: 0.5600835	total: 228ms	remaining: 5.47s
# 8:	learn: 0.5473839	total: 240ms	remaining: 5.1s
# 9:	learn: 0.5362531	total: 253ms	remaining: 4.8s
# 10:	learn: 0.5262788	total: 263ms	remaining: 4.52s
# 11:	learn: 0.5164546	total: 274ms	remaining: 4.3s
# 12:	learn: 0.5071562	total: 286ms	remaining: 4.12s
# 13:	learn: 0.4994334	total: 298ms	remaining: 3.96s
# 14:	learn: 0.4916756	total: 309ms	remaining: 3.81s
# 15:	learn: 0.4862753	total: 320ms	remaining: 3.67s
# 16:	learn: 0.4804789	total: 327ms	remaining: 3.52s
# 17:	learn: 0.4746878	total: 338ms	remaining: 3.42s
# 18:	learn: 0.4687787	total: 347ms	remaining: 3.31s
# 19:	learn: 0.4635559	total: 360ms	remaining: 3.24s
# 20:	learn: 0.4580795	total: 371ms	remaining: 3.16s
# 21:	learn: 0.4529465	total: 381ms	remaining: 3.08s
# 22:	learn: 0.4483063	total: 394ms	remaining: 3.03s
# 23:	learn: 0.4441084	total: 407ms	remaining: 2.98s
# 24:	learn: 0.4406722	total: 421ms	remaining: 2.95s
# 25:	learn: 0.4368064	total: 432ms	remaining: 2.89s
# 26:	learn: 0.4334064	total: 442ms	remaining: 2.83s
# 27:	learn: 0.4307198	total: 453ms	remaining: 2.78s
# 28:	learn: 0.4273881	total: 463ms	remaining: 2.73s
# 29:	learn: 0.4246353	total: 474ms	remaining: 2.68s
# 30:	learn: 0.4220274	total: 485ms	remaining: 2.64s
# 31:	learn: 0.4193261	total: 495ms	remaining: 2.6s
# 32:	learn: 0.4170343	total: 506ms	remaining: 2.56s
# 33:	learn: 0.4143407	total: 518ms	remaining: 2.53s
# 34:	learn: 0.4122255	total: 528ms	remaining: 2.49s
# 35:	learn: 0.4102231	total: 539ms	remaining: 2.46s
# 36:	learn: 0.4084107	total: 552ms	remaining: 2.43s
# 37:	learn: 0.4064225	total: 563ms	remaining: 2.4s
# 38:	learn: 0.4047967	total: 574ms	remaining: 2.37s
# 39:	learn: 0.4033283	total: 588ms	remaining: 2.35s
# 40:	learn: 0.4017979	total: 602ms	remaining: 2.33s
# 41:	learn: 0.4004660	total: 619ms	remaining: 2.33s
# 42:	learn: 0.3994885	total: 633ms	remaining: 2.31s
# 43:	learn: 0.3983623	total: 647ms	remaining: 2.29s
# 44:	learn: 0.3972290	total: 657ms	remaining: 2.26s
# 45:	learn: 0.3960105	total: 668ms	remaining: 2.24s
# 46:	learn: 0.3947340	total: 681ms	remaining: 2.21s
# 47:	learn: 0.3938570	total: 693ms	remaining: 2.19s
# 48:	learn: 0.3927239	total: 706ms	remaining: 2.17s
# 49:	learn: 0.3915199	total: 719ms	remaining: 2.16s
# 50:	learn: 0.3905319	total: 732ms	remaining: 2.14s
# 51:	learn: 0.3897950	total: 744ms	remaining: 2.12s
# 52:	learn: 0.3889767	total: 756ms	remaining: 2.1s
# 53:	learn: 0.3882561	total: 767ms	remaining: 2.07s
# 54:	learn: 0.3876325	total: 780ms	remaining: 2.06s
# 55:	learn: 0.3868290	total: 794ms	remaining: 2.04s
# 56:	learn: 0.3862850	total: 805ms	remaining: 2.02s
# 57:	learn: 0.3856172	total: 818ms	remaining: 2s
# 58:	learn: 0.3850548	total: 831ms	remaining: 1.99s
# 59:	learn: 0.3845464	total: 843ms	remaining: 1.97s
# 60:	learn: 0.3839476	total: 853ms	remaining: 1.94s
# 61:	learn: 0.3834429	total: 865ms	remaining: 1.93s
# 62:	learn: 0.3828706	total: 878ms	remaining: 1.91s
# 63:	learn: 0.3823322	total: 889ms	remaining: 1.89s
# 64:	learn: 0.3817952	total: 900ms	remaining: 1.87s
# 65:	learn: 0.3812611	total: 912ms	remaining: 1.85s
# 66:	learn: 0.3807146	total: 923ms	remaining: 1.83s
# 67:	learn: 0.3802737	total: 934ms	remaining: 1.81s
# 68:	learn: 0.3799076	total: 945ms	remaining: 1.79s
# 69:	learn: 0.3795211	total: 957ms	remaining: 1.78s
# 70:	learn: 0.3790239	total: 970ms	remaining: 1.76s
# 71:	learn: 0.3786376	total: 981ms	remaining: 1.74s
# 72:	learn: 0.3782691	total: 994ms	remaining: 1.73s
# 73:	learn: 0.3779739	total: 1.01s	remaining: 1.71s
# 74:	learn: 0.3776104	total: 1.02s	remaining: 1.7s
# 75:	learn: 0.3772505	total: 1.03s	remaining: 1.69s
# 76:	learn: 0.3769195	total: 1.05s	remaining: 1.68s
# 77:	learn: 0.3765777	total: 1.06s	remaining: 1.66s
# 78:	learn: 0.3762261	total: 1.07s	remaining: 1.65s
# 79:	learn: 0.3757805	total: 1.09s	remaining: 1.63s
# 80:	learn: 0.3755201	total: 1.1s	remaining: 1.62s
# 81:	learn: 0.3751576	total: 1.11s	remaining: 1.6s
# 82:	learn: 0.3747513	total: 1.13s	remaining: 1.59s
# 83:	learn: 0.3744414	total: 1.14s	remaining: 1.58s
# 84:	learn: 0.3740493	total: 1.16s	remaining: 1.57s
# 85:	learn: 0.3736933	total: 1.17s	remaining: 1.55s
# 86:	learn: 0.3735272	total: 1.19s	remaining: 1.54s
# 87:	learn: 0.3732023	total: 1.2s	remaining: 1.53s
# 88:	learn: 0.3729522	total: 1.21s	remaining: 1.51s
# 89:	learn: 0.3725725	total: 1.23s	remaining: 1.5s
# 90:	learn: 0.3724008	total: 1.24s	remaining: 1.49s
# 91:	learn: 0.3721271	total: 1.25s	remaining: 1.47s
# 92:	learn: 0.3718613	total: 1.27s	remaining: 1.46s
# 93:	learn: 0.3715907	total: 1.28s	remaining: 1.44s
# 94:	learn: 0.3713137	total: 1.29s	remaining: 1.43s
# 95:	learn: 0.3710830	total: 1.3s	remaining: 1.41s
# 96:	learn: 0.3708516	total: 1.32s	remaining: 1.4s
# 97:	learn: 0.3705742	total: 1.33s	remaining: 1.38s
# 98:	learn: 0.3703815	total: 1.34s	remaining: 1.37s
# 99:	learn: 0.3701550	total: 1.36s	remaining: 1.36s
# 100:	learn: 0.3699565	total: 1.37s	remaining: 1.34s
# 101:	learn: 0.3697118	total: 1.38s	remaining: 1.33s
# 102:	learn: 0.3694588	total: 1.39s	remaining: 1.31s
# 103:	learn: 0.3692105	total: 1.41s	remaining: 1.3s
# 104:	learn: 0.3689763	total: 1.42s	remaining: 1.28s
# 105:	learn: 0.3687821	total: 1.43s	remaining: 1.27s
# 106:	learn: 0.3685483	total: 1.45s	remaining: 1.26s
# 107:	learn: 0.3683430	total: 1.46s	remaining: 1.24s
# 108:	learn: 0.3681324	total: 1.47s	remaining: 1.23s
# 109:	learn: 0.3678845	total: 1.49s	remaining: 1.22s
# 110:	learn: 0.3676698	total: 1.5s	remaining: 1.2s
# 111:	learn: 0.3675793	total: 1.51s	remaining: 1.19s
# 112:	learn: 0.3673534	total: 1.52s	remaining: 1.17s
# 113:	learn: 0.3671647	total: 1.53s	remaining: 1.16s
# 114:	learn: 0.3670107	total: 1.54s	remaining: 1.14s
# 115:	learn: 0.3668191	total: 1.55s	remaining: 1.13s
# 116:	learn: 0.3666521	total: 1.57s	remaining: 1.11s
# 117:	learn: 0.3664473	total: 1.58s	remaining: 1.1s
# 118:	learn: 0.3662573	total: 1.59s	remaining: 1.08s
# 119:	learn: 0.3660166	total: 1.6s	remaining: 1.07s
# 120:	learn: 0.3658554	total: 1.61s	remaining: 1.05s
# 121:	learn: 0.3656634	total: 1.62s	remaining: 1.04s
# 122:	learn: 0.3654657	total: 1.64s	remaining: 1.03s
# 123:	learn: 0.3652687	total: 1.66s	remaining: 1.01s
# 124:	learn: 0.3651414	total: 1.67s	remaining: 1s
# 125:	learn: 0.3649778	total: 1.68s	remaining: 988ms
# 126:	learn: 0.3648333	total: 1.69s	remaining: 973ms
# 127:	learn: 0.3646360	total: 1.7s	remaining: 958ms
# 128:	learn: 0.3644329	total: 1.72s	remaining: 944ms
# 129:	learn: 0.3643126	total: 1.73s	remaining: 930ms
# 130:	learn: 0.3641449	total: 1.74s	remaining: 916ms
# 131:	learn: 0.3639512	total: 1.75s	remaining: 901ms
# 132:	learn: 0.3637134	total: 1.76s	remaining: 888ms
# 133:	learn: 0.3635497	total: 1.77s	remaining: 874ms
# 134:	learn: 0.3634067	total: 1.78s	remaining: 860ms
# 135:	learn: 0.3631750	total: 1.8s	remaining: 846ms
# 136:	learn: 0.3631603	total: 1.8s	remaining: 830ms
# 137:	learn: 0.3629998	total: 1.81s	remaining: 816ms
# 138:	learn: 0.3628129	total: 1.83s	remaining: 803ms
# 139:	learn: 0.3626826	total: 1.84s	remaining: 789ms
# 140:	learn: 0.3625327	total: 1.85s	remaining: 775ms
# 141:	learn: 0.3623679	total: 1.86s	remaining: 761ms
# 142:	learn: 0.3622050	total: 1.88s	remaining: 748ms
# 143:	learn: 0.3620566	total: 1.89s	remaining: 735ms
# 144:	learn: 0.3618948	total: 1.9s	remaining: 721ms
# 145:	learn: 0.3616898	total: 1.91s	remaining: 707ms
# 146:	learn: 0.3614366	total: 1.92s	remaining: 694ms
# 147:	learn: 0.3612998	total: 1.94s	remaining: 680ms
# 148:	learn: 0.3612074	total: 1.95s	remaining: 666ms
# 149:	learn: 0.3610460	total: 1.96s	remaining: 653ms
# 150:	learn: 0.3609135	total: 1.97s	remaining: 640ms
# 151:	learn: 0.3607457	total: 1.98s	remaining: 626ms
# 152:	learn: 0.3605454	total: 1.99s	remaining: 612ms
# 153:	learn: 0.3604003	total: 2s	remaining: 599ms
# 154:	learn: 0.3602885	total: 2.02s	remaining: 585ms
# 155:	learn: 0.3601198	total: 2.03s	remaining: 572ms
# 156:	learn: 0.3599626	total: 2.04s	remaining: 558ms
# 157:	learn: 0.3598416	total: 2.05s	remaining: 545ms
# 158:	learn: 0.3596965	total: 2.06s	remaining: 531ms
# 159:	learn: 0.3595804	total: 2.07s	remaining: 518ms
# 160:	learn: 0.3594962	total: 2.08s	remaining: 505ms
# 161:	learn: 0.3593251	total: 2.1s	remaining: 492ms
# 162:	learn: 0.3591569	total: 2.11s	remaining: 479ms
# 163:	learn: 0.3589670	total: 2.12s	remaining: 465ms
# 164:	learn: 0.3588772	total: 2.13s	remaining: 452ms
# 165:	learn: 0.3587185	total: 2.14s	remaining: 439ms
# 166:	learn: 0.3585930	total: 2.15s	remaining: 426ms
# 167:	learn: 0.3584846	total: 2.17s	remaining: 413ms
# 168:	learn: 0.3584428	total: 2.18s	remaining: 399ms
# 169:	learn: 0.3582690	total: 2.19s	remaining: 386ms
# 170:	learn: 0.3580931	total: 2.2s	remaining: 373ms
# 171:	learn: 0.3579853	total: 2.21s	remaining: 360ms
# 172:	learn: 0.3578000	total: 2.23s	remaining: 347ms
# 173:	learn: 0.3576476	total: 2.24s	remaining: 335ms
# 174:	learn: 0.3575671	total: 2.25s	remaining: 322ms
# 175:	learn: 0.3574744	total: 2.27s	remaining: 309ms
# 176:	learn: 0.3573278	total: 2.28s	remaining: 296ms
# 177:	learn: 0.3571692	total: 2.29s	remaining: 283ms
# 178:	learn: 0.3570265	total: 2.3s	remaining: 270ms
# 179:	learn: 0.3568156	total: 2.31s	remaining: 257ms
# 180:	learn: 0.3567468	total: 2.33s	remaining: 244ms
# 181:	learn: 0.3566133	total: 2.34s	remaining: 231ms
# 182:	learn: 0.3564900	total: 2.35s	remaining: 218ms
# 183:	learn: 0.3564107	total: 2.36s	remaining: 205ms
# 184:	learn: 0.3562704	total: 2.37s	remaining: 192ms
# 185:	learn: 0.3561348	total: 2.38s	remaining: 179ms
# 186:	learn: 0.3559895	total: 2.39s	remaining: 166ms
# 187:	learn: 0.3558328	total: 2.4s	remaining: 154ms
# 188:	learn: 0.3557518	total: 2.42s	remaining: 141ms
# 189:	learn: 0.3556025	total: 2.43s	remaining: 128ms
# 190:	learn: 0.3554717	total: 2.44s	remaining: 115ms
# 191:	learn: 0.3553463	total: 2.45s	remaining: 102ms
# 192:	learn: 0.3552380	total: 2.46s	remaining: 89.3ms
# 193:	learn: 0.3551202	total: 2.47s	remaining: 76.5ms
# 194:	learn: 0.3549646	total: 2.48s	remaining: 63.7ms
# 195:	learn: 0.3548373	total: 2.5s	remaining: 50.9ms
# 196:	learn: 0.3547600	total: 2.51s	remaining: 38.2ms
# 197:	learn: 0.3546263	total: 2.52s	remaining: 25.5ms
# 198:	learn: 0.3545029	total: 2.53s	remaining: 12.7ms
# 199:	learn: 0.3543468	total: 2.54s	remaining: 0us
# Fitting 4 folds for each of 20 candidates, totalling 80 fits
# 0:	learn: 0.6806792	total: 12.2ms	remaining: 2.43s
# 1:	learn: 0.6691390	total: 25.4ms	remaining: 2.51s
# 2:	learn: 0.6583261	total: 39.9ms	remaining: 2.62s
# 3:	learn: 0.6479492	total: 54.5ms	remaining: 2.67s
# 4:	learn: 0.6372475	total: 69.4ms	remaining: 2.71s
# 5:	learn: 0.6281357	total: 83.2ms	remaining: 2.69s
# 6:	learn: 0.6204599	total: 96.8ms	remaining: 2.67s
# 7:	learn: 0.6121711	total: 110ms	remaining: 2.64s
# 8:	learn: 0.6040729	total: 124ms	remaining: 2.63s
# 9:	learn: 0.5969890	total: 137ms	remaining: 2.61s
# 10:	learn: 0.5902520	total: 150ms	remaining: 2.58s
# 11:	learn: 0.5840183	total: 163ms	remaining: 2.55s
# 12:	learn: 0.5787771	total: 176ms	remaining: 2.53s
# 13:	learn: 0.5732860	total: 190ms	remaining: 2.53s
# 14:	learn: 0.5680411	total: 204ms	remaining: 2.52s
# 15:	learn: 0.5625781	total: 219ms	remaining: 2.52s
# 16:	learn: 0.5586416	total: 232ms	remaining: 2.49s
# 17:	learn: 0.5558141	total: 240ms	remaining: 2.43s
# 18:	learn: 0.5515072	total: 254ms	remaining: 2.42s
# 19:	learn: 0.5469934	total: 268ms	remaining: 2.41s
# 20:	learn: 0.5431548	total: 282ms	remaining: 2.41s
# 21:	learn: 0.5401631	total: 296ms	remaining: 2.39s
# 22:	learn: 0.5370556	total: 310ms	remaining: 2.39s
# 23:	learn: 0.5333920	total: 322ms	remaining: 2.36s
# 24:	learn: 0.5304109	total: 336ms	remaining: 2.35s
# 25:	learn: 0.5277487	total: 350ms	remaining: 2.34s
# 26:	learn: 0.5250298	total: 365ms	remaining: 2.34s
# 27:	learn: 0.5222928	total: 380ms	remaining: 2.33s
# 28:	learn: 0.5200367	total: 393ms	remaining: 2.32s
# 29:	learn: 0.5178279	total: 407ms	remaining: 2.31s
# 30:	learn: 0.5154905	total: 421ms	remaining: 2.29s
# 31:	learn: 0.5135755	total: 433ms	remaining: 2.27s
# 32:	learn: 0.5113066	total: 446ms	remaining: 2.26s
# 33:	learn: 0.5098194	total: 461ms	remaining: 2.25s
# 34:	learn: 0.5077604	total: 472ms	remaining: 2.23s
# 35:	learn: 0.5058814	total: 486ms	remaining: 2.21s
# 36:	learn: 0.5041399	total: 500ms	remaining: 2.2s
# 37:	learn: 0.5027900	total: 514ms	remaining: 2.19s
# 38:	learn: 0.5016185	total: 529ms	remaining: 2.18s
# 39:	learn: 0.5001302	total: 544ms	remaining: 2.17s
# 40:	learn: 0.4986949	total: 559ms	remaining: 2.17s
# 41:	learn: 0.4974499	total: 573ms	remaining: 2.16s
# 42:	learn: 0.4962372	total: 588ms	remaining: 2.15s
# 43:	learn: 0.4950862	total: 603ms	remaining: 2.14s
# 44:	learn: 0.4940727	total: 617ms	remaining: 2.12s
# 45:	learn: 0.4929324	total: 631ms	remaining: 2.11s
# 46:	learn: 0.4918051	total: 645ms	remaining: 2.1s
# 47:	learn: 0.4908099	total: 660ms	remaining: 2.09s
# 48:	learn: 0.4895699	total: 675ms	remaining: 2.08s
# 49:	learn: 0.4885985	total: 689ms	remaining: 2.07s
# 50:	learn: 0.4876081	total: 703ms	remaining: 2.05s
# 51:	learn: 0.4869007	total: 717ms	remaining: 2.04s
# 52:	learn: 0.4861820	total: 732ms	remaining: 2.03s
# 53:	learn: 0.4852612	total: 747ms	remaining: 2.02s
# 54:	learn: 0.4845812	total: 761ms	remaining: 2s
# 55:	learn: 0.4837877	total: 776ms	remaining: 2s
# 56:	learn: 0.4830459	total: 789ms	remaining: 1.98s
# 57:	learn: 0.4823739	total: 803ms	remaining: 1.97s
# 58:	learn: 0.4817001	total: 819ms	remaining: 1.96s
# 59:	learn: 0.4810685	total: 834ms	remaining: 1.95s
# 60:	learn: 0.4804910	total: 847ms	remaining: 1.93s
# 61:	learn: 0.4797849	total: 864ms	remaining: 1.92s
# 62:	learn: 0.4791469	total: 882ms	remaining: 1.92s
# 63:	learn: 0.4785573	total: 897ms	remaining: 1.91s
# 64:	learn: 0.4779872	total: 912ms	remaining: 1.89s
# 65:	learn: 0.4775053	total: 927ms	remaining: 1.88s
# 66:	learn: 0.4770562	total: 942ms	remaining: 1.87s
# 67:	learn: 0.4764979	total: 957ms	remaining: 1.86s
# 68:	learn: 0.4760128	total: 972ms	remaining: 1.85s
# 69:	learn: 0.4755803	total: 990ms	remaining: 1.84s
# 70:	learn: 0.4753830	total: 999ms	remaining: 1.81s
# 71:	learn: 0.4748391	total: 1.01s	remaining: 1.8s
# 72:	learn: 0.4744006	total: 1.03s	remaining: 1.79s
# 73:	learn: 0.4740136	total: 1.04s	remaining: 1.78s
# 74:	learn: 0.4736138	total: 1.06s	remaining: 1.77s
# 75:	learn: 0.4731430	total: 1.08s	remaining: 1.76s
# 76:	learn: 0.4727562	total: 1.09s	remaining: 1.75s
# 77:	learn: 0.4722603	total: 1.11s	remaining: 1.74s
# 78:	learn: 0.4719276	total: 1.13s	remaining: 1.72s
# 79:	learn: 0.4715407	total: 1.14s	remaining: 1.71s
# 80:	learn: 0.4711808	total: 1.16s	remaining: 1.7s
# 81:	learn: 0.4709245	total: 1.17s	remaining: 1.69s
# 82:	learn: 0.4705843	total: 1.19s	remaining: 1.67s
# 83:	learn: 0.4702806	total: 1.2s	remaining: 1.66s
# 84:	learn: 0.4700283	total: 1.22s	remaining: 1.65s
# 85:	learn: 0.4696268	total: 1.24s	remaining: 1.64s
# 86:	learn: 0.4693495	total: 1.25s	remaining: 1.63s
# 87:	learn: 0.4690903	total: 1.27s	remaining: 1.61s
# 88:	learn: 0.4687535	total: 1.29s	remaining: 1.6s
# 89:	learn: 0.4685141	total: 1.3s	remaining: 1.59s
# 90:	learn: 0.4682423	total: 1.32s	remaining: 1.58s
# 91:	learn: 0.4678429	total: 1.33s	remaining: 1.56s
# 92:	learn: 0.4675491	total: 1.35s	remaining: 1.55s
# 93:	learn: 0.4672207	total: 1.36s	remaining: 1.54s
# 94:	learn: 0.4669771	total: 1.38s	remaining: 1.52s
# 95:	learn: 0.4667854	total: 1.39s	remaining: 1.51s
# 96:	learn: 0.4666193	total: 1.41s	remaining: 1.49s
# 97:	learn: 0.4663182	total: 1.42s	remaining: 1.48s
# 98:	learn: 0.4661003	total: 1.44s	remaining: 1.47s
# 99:	learn: 0.4658705	total: 1.45s	remaining: 1.45s
# 100:	learn: 0.4655467	total: 1.47s	remaining: 1.44s
# 101:	learn: 0.4652846	total: 1.48s	remaining: 1.42s
# 102:	learn: 0.4650038	total: 1.5s	remaining: 1.41s
# 103:	learn: 0.4646655	total: 1.51s	remaining: 1.4s
# 104:	learn: 0.4644102	total: 1.53s	remaining: 1.38s
# 105:	learn: 0.4641979	total: 1.54s	remaining: 1.37s
# 106:	learn: 0.4640162	total: 1.56s	remaining: 1.35s
# 107:	learn: 0.4637595	total: 1.57s	remaining: 1.34s
# 108:	learn: 0.4634854	total: 1.59s	remaining: 1.32s
# 109:	learn: 0.4631711	total: 1.6s	remaining: 1.31s
# 110:	learn: 0.4629665	total: 1.62s	remaining: 1.3s
# 111:	learn: 0.4627280	total: 1.63s	remaining: 1.28s
# 112:	learn: 0.4625037	total: 1.65s	remaining: 1.27s
# 113:	learn: 0.4622784	total: 1.66s	remaining: 1.25s
# 114:	learn: 0.4621098	total: 1.68s	remaining: 1.24s
# 115:	learn: 0.4619080	total: 1.69s	remaining: 1.22s
# 116:	learn: 0.4618521	total: 1.7s	remaining: 1.2s
# 117:	learn: 0.4615871	total: 1.71s	remaining: 1.19s
# 118:	learn: 0.4613896	total: 1.73s	remaining: 1.18s
# 119:	learn: 0.4612006	total: 1.74s	remaining: 1.16s
# 120:	learn: 0.4609827	total: 1.76s	remaining: 1.15s
# 121:	learn: 0.4607636	total: 1.78s	remaining: 1.14s
# 122:	learn: 0.4605876	total: 1.79s	remaining: 1.12s
# 123:	learn: 0.4603911	total: 1.8s	remaining: 1.11s
# 124:	learn: 0.4601316	total: 1.82s	remaining: 1.09s
# 125:	learn: 0.4599107	total: 1.83s	remaining: 1.08s
# 126:	learn: 0.4597003	total: 1.85s	remaining: 1.06s
# 127:	learn: 0.4594834	total: 1.86s	remaining: 1.05s
# 128:	learn: 0.4593083	total: 1.88s	remaining: 1.03s
# 129:	learn: 0.4591171	total: 1.89s	remaining: 1.02s
# 130:	learn: 0.4589362	total: 1.91s	remaining: 1s
# 131:	learn: 0.4586970	total: 1.92s	remaining: 990ms
# 132:	learn: 0.4585593	total: 1.94s	remaining: 976ms
# 133:	learn: 0.4583849	total: 1.95s	remaining: 961ms
# 134:	learn: 0.4582124	total: 1.97s	remaining: 947ms
# 135:	learn: 0.4580210	total: 1.98s	remaining: 932ms
# 136:	learn: 0.4578939	total: 1.99s	remaining: 917ms
# 137:	learn: 0.4577289	total: 2.01s	remaining: 902ms
# 138:	learn: 0.4575338	total: 2.02s	remaining: 888ms
# 139:	learn: 0.4573541	total: 2.04s	remaining: 873ms
# 140:	learn: 0.4571639	total: 2.05s	remaining: 858ms
# 141:	learn: 0.4569775	total: 2.06s	remaining: 842ms
# 142:	learn: 0.4567679	total: 2.07s	remaining: 827ms
# 143:	learn: 0.4566170	total: 2.08s	remaining: 811ms
# 144:	learn: 0.4565058	total: 2.1s	remaining: 796ms
# 145:	learn: 0.4563852	total: 2.11s	remaining: 781ms
# 146:	learn: 0.4562465	total: 2.12s	remaining: 766ms
# 147:	learn: 0.4560313	total: 2.14s	remaining: 751ms
# 148:	learn: 0.4558791	total: 2.15s	remaining: 736ms
# 149:	learn: 0.4557454	total: 2.16s	remaining: 721ms
# 150:	learn: 0.4555714	total: 2.17s	remaining: 705ms
# 151:	learn: 0.4554045	total: 2.18s	remaining: 690ms
# 152:	learn: 0.4552663	total: 2.2s	remaining: 675ms
# 153:	learn: 0.4551165	total: 2.21s	remaining: 659ms
# 154:	learn: 0.4550502	total: 2.22s	remaining: 644ms
# 155:	learn: 0.4549122	total: 2.23s	remaining: 629ms
# 156:	learn: 0.4547233	total: 2.24s	remaining: 614ms
# 157:	learn: 0.4545173	total: 2.25s	remaining: 599ms
# 158:	learn: 0.4543539	total: 2.26s	remaining: 584ms
# 159:	learn: 0.4541986	total: 2.27s	remaining: 569ms
# 160:	learn: 0.4540604	total: 2.29s	remaining: 554ms
# 161:	learn: 0.4539850	total: 2.3s	remaining: 539ms
# 162:	learn: 0.4537972	total: 2.31s	remaining: 525ms
# 163:	learn: 0.4536078	total: 2.33s	remaining: 510ms
# 164:	learn: 0.4534262	total: 2.34s	remaining: 496ms
# 165:	learn: 0.4532525	total: 2.35s	remaining: 482ms
# 166:	learn: 0.4530511	total: 2.36s	remaining: 467ms
# 167:	learn: 0.4529385	total: 2.38s	remaining: 453ms
# 168:	learn: 0.4528593	total: 2.39s	remaining: 438ms
# 169:	learn: 0.4527225	total: 2.4s	remaining: 423ms
# 170:	learn: 0.4525599	total: 2.41s	remaining: 409ms
# 171:	learn: 0.4524016	total: 2.42s	remaining: 395ms
# 172:	learn: 0.4522697	total: 2.44s	remaining: 381ms
# 173:	learn: 0.4520973	total: 2.45s	remaining: 366ms
# 174:	learn: 0.4519919	total: 2.46s	remaining: 352ms
# 175:	learn: 0.4518334	total: 2.48s	remaining: 338ms
# 176:	learn: 0.4516962	total: 2.49s	remaining: 323ms
# 177:	learn: 0.4515656	total: 2.5s	remaining: 309ms
# 178:	learn: 0.4514108	total: 2.51s	remaining: 295ms
# 179:	learn: 0.4512887	total: 2.52s	remaining: 281ms
# 180:	learn: 0.4510874	total: 2.54s	remaining: 267ms
# 181:	learn: 0.4508977	total: 2.55s	remaining: 252ms
# 182:	learn: 0.4507382	total: 2.56s	remaining: 238ms
# 183:	learn: 0.4505604	total: 2.58s	remaining: 224ms
# 184:	learn: 0.4504058	total: 2.59s	remaining: 210ms
# 185:	learn: 0.4502718	total: 2.6s	remaining: 196ms
# 186:	learn: 0.4501575	total: 2.61s	remaining: 182ms
# 187:	learn: 0.4500205	total: 2.62s	remaining: 168ms
# 188:	learn: 0.4498395	total: 2.64s	remaining: 154ms
# 189:	learn: 0.4496563	total: 2.65s	remaining: 139ms
# 190:	learn: 0.4495398	total: 2.66s	remaining: 125ms
# 191:	learn: 0.4494201	total: 2.67s	remaining: 111ms
# 192:	learn: 0.4492570	total: 2.69s	remaining: 97.5ms
# 193:	learn: 0.4491280	total: 2.7s	remaining: 83.5ms
# 194:	learn: 0.4489715	total: 2.71s	remaining: 69.5ms
# 195:	learn: 0.4488720	total: 2.72s	remaining: 55.6ms
# 196:	learn: 0.4487522	total: 2.74s	remaining: 41.7ms
# 197:	learn: 0.4486104	total: 2.75s	remaining: 27.8ms
# 198:	learn: 0.4484433	total: 2.77s	remaining: 13.9ms
# 199:	learn: 0.4482901	total: 2.78s	remaining: 0us
# Training Accuracy is :  86.8137107341462
# Cross Validation Accuracy is :  83.73937583911672

# %%
classifier = CatBoostClassifier(
n_estimators = 300,depth = 5,l2_leaf_reg =0.5,
                                random_seed = 2,colsample_bylevel = 0.9,verbose = False)

# %%
clf = BinaryRelevance(classifier=classifier, require_dense=[True,True])
clf.fit(x_train,y_train)
find_acc(clf,x_train,y_train,'Training')
find_acc(clf,x_test,y_test,'Cross Validation')
# Out:
# Training Accuracy is :  86.00514429963677
# Cross Validation Accuracy is :  83.80170303862877

# %%
submission = clf.predict_proba(Test_X.values)
submission_df = pd.DataFrame.sparse.from_spmatrix(submission)

# %%
trial = submission_df
trial['respondent_id'] = trial.index+26707 # Converting the default indices
trial['h1n1_vaccine'] = trial[0].astype('float64') # Data required to be in float64 
trial['seasonal_vaccine'] = trial[1].astype('float64')
trial.set_index('respondent_id') # Make index as respondent_id
trial.drop([0,1],axis=1,inplace=True) # Drop old index axis
submission_df = trial

# %%
submission_df
# Out:
#        respondent_id  h1n1_vaccine  seasonal_vaccine
# 0              26707      0.107841          0.191130
# 1              26708      0.042384          0.046619
# 2              26709      0.360907          0.709009
# 3              26710      0.507392          0.891375
# 4              26711      0.393687          0.638935
# ...              ...           ...               ...
# 26703          53410      0.262672          0.425711
# 26704          53411      0.179365          0.368788
# 26705          53412      0.131889          0.162011
# 26706          53413      0.075921          0.364903
# 26707          53414      0.431806          0.502709
#
# [26708 rows x 3 columns]

# %%
submission_df.to_csv('Submission.csv',index = False)
